# %% [markdown]
# <a href="https://colab.research.google.com/github/kp0402/demopygit/blob/main/visual_object_tracking.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# clone YOLOv5 repository
# !git clone https://github.com/ultralytics/yolov5  # clone repo
# %cd yolov5
# !git reset --hard fbe67e465375231474a2ad80a4389efc77ecff99
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 14474, done.
# remote: Counting objects: 100% (103/103), done.
# remote: Compressing objects: 100% (60/60), done.
# remote: Total 14474 (delta 65), reused 68 (delta 42), pack-reused 14371
# Receiving objects: 100% (14474/14474), 13.66 MiB | 30.61 MiB/s, done.
# Resolving deltas: 100% (9959/9959), done.
# /content/yolov5
# HEAD is now at fbe67e4 Fix `OMP_NUM_THREADS=1` for macOS (#8624)

# %% [markdown]
#  # FOR UPDATING YOLOV5
#
#  this is because yolov5 gets constantly update in real time

# %%
# !git pull https://github.com/ultralytics/yolov5
# Out:
# From https://github.com/ultralytics/yolov5
#  * branch            HEAD       -> FETCH_HEAD
# Updating fbe67e4..357cde9
# Fast-forward
#  utils/docker/.dockerignore => .dockerignore |    2 +-
#  .github/README_cn.md                        |  291 ------
#  .github/workflows/ci-testing.yml            |  134 ++-
#  .github/workflows/docker.yml                |    3 +
#  .github/workflows/greetings.yml             |   22 +-
#  .github/workflows/rebase.yml                |   21 -
#  .github/workflows/stale.yml                 |    2 +-
#  .github/workflows/translate-readme.yml      |   27 +
#  .pre-commit-config.yaml                     |   14 +-
#  CITATION.cff                                |   14 +
#  CONTRIBUTING.md                             |   23 +-
#  README.md                                   |  486 ++++++---
#  README.zh-CN.md                             |  482 +++++++++
#  utils/benchmarks.py => benchmarks.py        |   32 +-
#  classify/predict.py                         |  226 ++++
#  classify/train.py                           |  333 ++++++
#  classify/tutorial.ipynb                     | 1479 +++++++++++++++++++++++++++
#  classify/val.py                             |  170 +++
#  data/Argoverse.yaml                         |   13 +-
#  data/GlobalWheat2020.yaml                   |    4 +-
#  data/ImageNet.yaml                          | 1022 ++++++++++++++++++
#  data/Objects365.yaml                        |  408 +++++++-
#  data/SKU-110K.yaml                          |    4 +-
#  data/VOC.yaml                               |   29 +-
#  data/VisDrone.yaml                          |   13 +-
#  data/coco.yaml                              |   91 +-
#  data/coco128-seg.yaml                       |  101 ++
#  data/coco128.yaml                           |   91 +-
#  data/scripts/download_weights.sh            |   12 +-
#  data/scripts/get_coco.sh                    |   45 +-
#  data/scripts/get_coco128.sh                 |    2 +-
#  data/scripts/get_imagenet.sh                |   51 +
#  data/xView.yaml                             |   73 +-
#  detect.py                                   |  121 +--
#  export.py                                   |  793 +++++++-------
#  hubconf.py                                  |   56 +-
#  models/common.py                            |  534 ++++++----
#  models/experimental.py                      |   21 +-
#  models/hub/yolov5s-LeakyReLU.yaml           |   49 +
#  models/segment/yolov5l-seg.yaml             |   48 +
#  models/segment/yolov5m-seg.yaml             |   48 +
#  models/segment/yolov5n-seg.yaml             |   48 +
#  models/segment/yolov5s-seg.yaml             |   48 +
#  models/segment/yolov5x-seg.yaml             |   48 +
#  models/tf.py                                |   60 +-
#  models/yolo.py                              |  237 +++--
#  requirements.txt                            |   39 +-
#  segment/predict.py                          |  284 +++++
#  segment/train.py                            |  658 ++++++++++++
#  segment/tutorial.ipynb                      |  593 +++++++++++
#  segment/val.py                              |  472 +++++++++
#  setup.cfg                                   |   25 +-
#  train.py                                    |  191 ++--
#  tutorial.ipynb                              |  676 +++++-------
#  utils/__init__.py                           |   48 +-
#  utils/augmentations.py                      |  133 ++-
#  utils/autoanchor.py                         |   25 +-
#  utils/autobatch.py                          |   18 +-
#  utils/callbacks.py                          |   13 +-
#  utils/dataloaders.py                        |  594 ++++++-----
#  utils/docker/Dockerfile                     |   15 +-
#  utils/docker/Dockerfile-arm64               |   17 +-
#  utils/docker/Dockerfile-cpu                 |   15 +-
#  utils/downloads.py                          |  116 +--
#  utils/flask_rest_api/restapi.py             |   18 +-
#  utils/general.py                            |  558 ++++++----
#  utils/loggers/__init__.py                   |  302 +++++-
#  utils/loggers/clearml/README.md             |  230 +++++
#  utils/loggers/clearml/__init__.py           |    0
#  utils/loggers/clearml/clearml_utils.py      |  164 +++
#  utils/loggers/clearml/hpo.py                |   84 ++
#  utils/loggers/comet/README.md               |  256 +++++
#  utils/loggers/comet/__init__.py             |  508 +++++++++
#  utils/loggers/comet/comet_utils.py          |  150 +++
#  utils/loggers/comet/hpo.py                  |  118 +++
#  utils/loggers/comet/optimizer_config.json   |  209 ++++
#  utils/loggers/wandb/wandb_utils.py          |   16 +-
#  utils/metrics.py                            |  123 +--
#  utils/plots.py                              |  116 ++-
#  utils/segment/__init__.py                   |    0
#  utils/segment/augmentations.py              |  104 ++
#  utils/segment/dataloaders.py                |  331 ++++++
#  utils/segment/general.py                    |  160 +++
#  utils/segment/loss.py                       |  186 ++++
#  utils/segment/metrics.py                    |  210 ++++
#  utils/segment/plots.py                      |  143 +++
#  utils/torch_utils.py                        |  150 ++-
#  utils/triton.py                             |   85 ++
#  val.py                                      |  136 +--
#  89 files changed, 13310 insertions(+), 2810 deletions(-)
#  rename utils/docker/.dockerignore => .dockerignore (99%)
#  delete mode 100644 .github/README_cn.md
#  delete mode 100644 .github/workflows/rebase.yml
#  create mode 100644 .github/workflows/translate-readme.yml
#  create mode 100644 CITATION.cff
#  create mode 100644 README.zh-CN.md
#  rename utils/benchmarks.py => benchmarks.py (79%)
#  create mode 100644 classify/predict.py
#  create mode 100644 classify/train.py
#  create mode 100644 classify/tutorial.ipynb
#  create mode 100644 classify/val.py
#  create mode 100644 data/ImageNet.yaml
#  create mode 100644 data/coco128-seg.yaml
#  mode change 100644 => 100755 data/scripts/get_coco128.sh
#  create mode 100755 data/scripts/get_imagenet.sh
#  create mode 100644 models/hub/yolov5s-LeakyReLU.yaml
#  create mode 100644 models/segment/yolov5l-seg.yaml
#  create mode 100644 models/segment/yolov5m-seg.yaml
#  create mode 100644 models/segment/yolov5n-seg.yaml
#  create mode 100644 models/segment/yolov5s-seg.yaml
#  create mode 100644 models/segment/yolov5x-seg.yaml
#  create mode 100644 segment/predict.py
#  create mode 100644 segment/train.py
#  create mode 100644 segment/tutorial.ipynb
#  create mode 100644 segment/val.py
#  mode change 100755 => 100644 utils/dataloaders.py
#  mode change 100755 => 100644 utils/general.py
#  create mode 100644 utils/loggers/clearml/README.md
#  create mode 100644 utils/loggers/clearml/__init__.py
#  create mode 100644 utils/loggers/clearml/clearml_utils.py
#  create mode 100644 utils/loggers/clearml/hpo.py
#  create mode 100644 utils/loggers/comet/README.md
#  create mode 100644 utils/loggers/comet/__init__.py
#  create mode 100644 utils/loggers/comet/comet_utils.py
#  create mode 100644 utils/loggers/comet/hpo.py
#  create mode 100644 utils/loggers/comet/optimizer_config.json
#  create mode 100644 utils/segment/__init__.py
#  create mode 100644 utils/segment/augmentations.py
#  create mode 100644 utils/segment/dataloaders.py
#  create mode 100644 utils/segment/general.py
#  create mode 100644 utils/segment/loss.py
#  create mode 100644 utils/segment/metrics.py
#  create mode 100644 utils/segment/plots.py
#  create mode 100644 utils/triton.py

# %% [markdown]
#   # Installing Requirements for yolov5

# %%
# install dependencies as necessary
# !pip install -qr requirements.txt  # install dependencies (ignore errors)
# Out:
#      |████████████████████████████████| 182 kB 5.0 MB/s
#      |████████████████████████████████| 62 kB 1.5 MB/s
#      |████████████████████████████████| 1.6 MB 73.5 MB/s

# %% [markdown]
# # Setting up GPUs of google Colab to run yolov5

# %%
import torch

from IPython.display import Image, clear_output  # to display images
from utils.downloads import attempt_download  # to download models/datasets

# clear_output()
print('Setup complete. Using torch %s %s' % (torch.__version__, torch.cuda.get_device_properties(0) if torch.cuda.is_available() else 'CPU'))
# Out:
# Setup complete. Using torch 1.13.0+cu116 _CudaDeviceProperties(name='Tesla T4', major=7, minor=5, total_memory=15109MB, multi_processor_count=40)

# %% [markdown]
# # Downloading dataset directly from roboflow

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="c3C6eciXJl8EjBEfur9S")
project = rf.workspace("mcmaster-v90vf").project("visual_object_tracking")
dataset = project.version(2).download("yolov5")
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting roboflow
#   Downloading roboflow-0.2.21-py3-none-any.whl (42 kB)
#      |████████████████████████████████| 42 kB 894 kB/s
# Requirement already satisfied: numpy>=1.18.5 in /usr/local/lib/python3.8/dist-packages (from roboflow) (1.21.6)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.8/dist-packages (from roboflow) (1.4.4)
# Collecting certifi==2021.5.30
#   Downloading certifi-2021.5.30-py2.py3-none-any.whl (145 kB)
#      |████████████████████████████████| 145 kB 8.4 MB/s
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.8/dist-packages (from roboflow) (3.2.2)
# Requirement already satisfied: idna==2.10 in /usr/local/lib/python3.8/dist-packages (from roboflow) (2.10)
# Requirement already satisfied: requests in /usr/local/lib/python3.8/dist-packages (from roboflow) (2.23.0)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.8/dist-packages (from roboflow) (2.8.2)
# Requirement already satisfied: Pillow>=7.1.2 in /usr/local/lib/python3.8/dist-packages (from roboflow) (7.1.2)
# Requirement already satisfied: six in /usr/local/lib/python3.8/dist-packages (from roboflow) (1.15.0)
# Collecting chardet==4.0.0
#   Downloading chardet-4.0.0-py2.py3-none-any.whl (178 kB)
#      |████████████████████████████████| 178 kB 39.8 MB/s
# Collecting python-dotenv
#   Downloading python_dotenv-0.21.0-py3-none-any.whl (18 kB)
# Collecting wget
#   Downloading wget-3.2.zip (10 kB)
# Collecting pyparsing==2.4.7
#   Downloading pyparsing-2.4.7-py2.py3-none-any.whl (67 kB)
#      |████████████████████████████████| 67 kB 6.9 MB/s
# Requirement already satisfied: glob2 in /usr/local/lib/python3.8/dist-packages (from roboflow) (0.7)
# Collecting urllib3==1.26.6
#   Downloading urllib3-1.26.6-py2.py3-none-any.whl (138 kB)
#      |████████████████████████████████| 138 kB 68.7 MB/s
# Requirement already satisfied: PyYAML>=5.3.1 in /usr/local/lib/python3.8/dist-packages (from roboflow) (6.0)
# Collecting cycler==0.10.0
#   Downloading cycler-0.10.0-py2.py3-none-any.whl (6.5 kB)
# Requirement already satisfied: tqdm>=4.41.0 in /usr/local/lib/python3.8/dist-packages (from roboflow) (4.64.1)
# Collecting requests-toolbelt
#   Downloading requests_toolbelt-0.10.1-py2.py3-none-any.whl (54 kB)
#      |████████████████████████████████| 54 kB 1.7 MB/s
# Requirement already satisfied: opencv-python-headless>=4.5.1.48 in /usr/local/lib/python3.8/dist-packages (from roboflow) (4.6.0.66)
# Collecting requests
#   Downloading requests-2.28.1-py3-none-any.whl (62 kB)
#      |████████████████████████████████| 62 kB 1.5 MB/s
# Requirement already satisfied: charset-normalizer<3,>=2 in /usr/local/lib/python3.8/dist-packages (from requests->roboflow) (2.1.1)
# Building wheels for collected packages: wget
#   Building wheel for wget (setup.py) ... done
#   Created wheel for wget: filename=wget-3.2-py3-none-any.whl size=9674 sha256=cc59e22a7893fd7f388023f87dc13e2f95331988116d7a331cd72eb7ec795b2d
#   Stored in directory: /root/.cache/pip/wheels/bd/a8/c3/3cf2c14a1837a4e04bd98631724e81f33f462d86a1d895fae0
# Successfully built wget
# Installing collected packages: urllib3, certifi, requests, pyparsing, cycler, wget, requests-toolbelt, python-dotenv, chardet, roboflow
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.24.3
#     Uninstalling urllib3-1.24.3:
#       Successfully uninstalled urllib3-1.24.3
#   Attempting uninstall: certifi
#     Found existing installation: certifi 2022.9.24
#     Uninstalling certifi-2022.9.24:
#       Successfully uninstalled certifi-2022.9.24
#   Attempting uninstall: requests
#     Found existing installation: requests 2.23.0
#     Uninstalling requests-2.23.0:
#       Successfully uninstalled requests-2.23.0
#   Attempting uninstall: pyparsing
#     Found existing installation: pyparsing 3.0.9
#     Uninstalling pyparsing-3.0.9:
#       Successfully uninstalled pyparsing-3.0.9
#   Attempting uninstall: cycler
#     Found existing installation: cycler 0.11.0
#     Uninstalling cycler-0.11.0:
#       Successfully uninstalled cycler-0.11.0
#   Attempting uninstall: chardet
#     Found existing installation: chardet 3.0.4
#     Uninstalling chardet-3.0.4:
#       Successfully uninstalled chardet-3.0.4
# Successfully installed certifi-2021.5.30 chardet-4.0.0 cycler-0.10.0 pyparsing-2.4.7 python-dotenv-0.21.0 requests-2.28.1 requests-toolbelt-0.10.1 roboflow-0.2.21 urllib3-1.26.6 wget-3.2
# loading Roboflow workspace...
# loading Roboflow project...
# Downloading Dataset Version Zip in visual_object_tracking-2 to yolov5pytorch: 99% [98492416 / 98817191] bytes
# Extracting Dataset Version Zip to visual_object_tracking-2 in yolov5pytorch:: 100%|██████████| 6176/6176 [00:01<00:00, 3630.51it/s]

# %% [markdown]
# # Defining Number of Classes

# %%
import yaml
with open("/content/yolov5/visual_object_tracking-2/data.yaml", 'r') as rf:
    all_classes = str(yaml.safe_load(rf)['nc'])

# %% [markdown]
# # Model we will use for detection

# %%
#this is the model configuration we will use for our tutorial 
# %cat /content/yolov5/models/yolov5s.yaml
# Out:
# # YOLOv5 🚀 by Ultralytics, GPL-3.0 license
#
# # Parameters
# nc: 80  # number of classes
# depth_multiple: 0.33  # model depth multiple
# width_multiple: 0.50  # layer channel multiple
# anchors:
#   - [10,13, 16,30, 33,23]  # P3/8
#   - [30,61, 62,45, 59,119]  # P4/16
#   - [116,90, 156,198, 373,326]  # P5/32
#
# # YOLOv5 v6.0 backbone
# backbone:
#   # [from, number, module, args]
#   [[-1, 1, Conv, [64, 6, 2, 2]],  # 0-P1/2
#    [-1, 1, Conv, [128, 3, 2]],  # 1-P2/4
#    [-1, 3, C3, [128]],
#    [-1, 1, Conv, [256, 3, 2]],  # 3-P3/8
#    [-1, 6, C3, [256]],
#    [-1, 1, Conv, [512, 3, 2]],  # 5-P4/16
#    [-1, 9, C3, [512]],
#    [-1, 1, Conv, [1024, 3, 2]],  # 7-P5/32
#    [-1, 3, C3, [1024]],
#    [-1, 1, SPPF, [1024, 5]],  # 9
#   ]
#
# # YOLOv5 v6.0 head
# head:
#   [[-1, 1, Conv, [512, 1, 1]],
#    [-1, 1, nn.Upsample, [None, 2, 'nearest']],
#    [[-1, 6], 1, Concat, [1]],  # cat backbone P4
#    [-1, 3, C3, [512, False]],  # 13
#
#    [-1, 1, Conv, [256, 1, 1]],
#    [-1, 1, nn.Upsample, [None, 2, 'nearest']],
#    [[-1, 4], 1, Concat, [1]],  # cat backbone P3
#    [-1, 3, C3, [256, False]],  # 17 (P3/8-small)
#
#    [-1, 1, Conv, [256, 3, 2]],
#    [[-1, 14], 1, Concat, [1]],  # cat head P4
#    [-1, 3, C3, [512, False]],  # 20 (P4/16-medium)
#
#    [-1, 1, Conv, [512, 3, 2]],
#    [[-1, 10], 1, Concat, [1]],  # cat head P5
#    [-1, 3, C3, [1024, False]],  # 23 (P5/32-large)
#
#    [[17, 20, 23], 1, Detect, [nc, anchors]],  # Detect(P3, P4, P5)
#   ]

# %% [markdown]
# # Training YOLOv5 Detector
#
# Here we use image size of 640 * 640
#
# batch size = 64
#
# and we run this for 100 epochs using yolov5s model
#
# saving weights with name yolov5s_results
#
# caching the image for faster training

# %%
# train yolov5s on custom data for 100 epochs
# time its performance
# %%time
# %cd /content/yolov5
# !python train.py --img 640 --batch 64 --epochs 100 --data '/content/yolov5/visual_object_tracking-2/data.yaml' --cfg ./models/yolov5s.yaml --weights '' --name yolov5s_results --cache
# Out:
# /content/yolov5
# train: weights=, cfg=./models/yolov5s.yaml, data=/content/yolov5/visual_object_tracking-2/data.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=100, batch_size=64, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=ram, image_weights=False, device=0, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=yolov5s_results, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# Traceback (most recent call last):
#   File "train.py", line 633, in <module>
#     main(opt)
#   File "train.py", line 513, in main
#     device = select_device(opt.device, batch_size=opt.batch_size)
#   File "/content/yolov5/utils/torch_utils.py", line 118, in select_device
#     assert torch.cuda.is_available() and torch.cuda.device_count() >= len(device.replace(',', '')), \
# AssertionError: Invalid CUDA '--device 0' requested, use '--device cpu' or pass valid CUDA device(s)
# CPU times: user 104 ms, sys: 19.6 ms, total: 124 ms
# Wall time: 12.3 s

# %% [markdown]
# # Evaluating YOLOv5s Performance on our dataset

# %%
# we can also output some older school graphs if the tensor board isn't working for whatever reason... 
from utils.plots import plot_results  # plot results.txt as results.png
Image(filename='/content/yolov5/runs/train/yolov5s_results2/results.png', width=1000)  # view results.png

# %% [markdown]
# # Visualizing Training Data and Validation Data

# %%
# first, display our ground truth data
print("GROUND TRUTH TRAINING DATA:")
Image(filename='/content/yolov5/runs/train/yolov5s_results2/train_batch1.jpg', width=900)
# Out:
# GROUND TRUTH TRAINING DATA:

# %%
# print out an augmented training example
print("GROUND TRUTH AUGMENTED TRAINING DATA:")
Image(filename='/content/yolov5/runs/train/yolov5s_results2/val_batch1_labels.jpg', width=900)
# Out:
# GROUND TRUTH AUGMENTED TRAINING DATA:

# %% [markdown]
# #Running best parameter from trained data on test images with threshold of 40%

# %%
# use the best weights!
# %cd /content/yolov5/
# !python detect.py --weights runs/train/yolov5s_results2/weights/best.pt --img 640 --conf 0.4 --source /content/yolov5/visual_object_tracking-2/test/images
# Out:
# /content/yolov5
# detect: weights=['runs/train/yolov5s_results2/weights/best.pt'], source=/content/yolov5/visual_object_tracking-2/test/images, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.4, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0
# image 19/165 /content/yolov5/visual_object_tracking-2/test/images/0047_jpg.rf.48f0380d08251f4fa286cbde0776d63f.jpg: 640x640 1 Biker, 10.5ms
# image 20/165 /content/yolov5/visual_object_tracking-2/test/images/0047_jpg.rf.f78ae56f328c8a1b33a7d38692937ecf.jpg: 640x640 1 bird1, 10.5ms
# image 21/165 /content/yolov5/visual_object_tracking-2/test/images/0053_jpg.rf.631a08b2bc783fb45a069efb8f1f2736.jpg: 640x640 1 bird1, 10.5ms
# image 22/165 /content/yolov5/visual_object_tracking-2/test/images/0059_jpg.rf.92164e481dcf20b680f9fb658140ef07.jpg: 640x640 1 bird1, 10.5ms
# image 23/165 /content/yolov5/visual_object_tracking-2/test/images/0061_jpg.rf.483bb6c9e8625e1ccf255d26c7abba05.jpg: 640x640 1 blurcar, 10.3ms
# image 24/165 /content/yolov5/visual_object_tracking-2/test/images/0062_jpg.rf.a6e31b1a90d68c80fbbe7cd4e1717d66.jpg: 640x640 1 Biker, 9.4ms
# image 25/165 /content/yolov5/visual_object_tracking-2/test/images/0063_jpg.rf.4c2afcb2951688781ad2ab256b12ff98.jpg: 640x640 1 bird1, 9.4ms
# image 26/165 /content/yolov5/visual_object_tracking-2/test/images/0063_jpg.rf.de9f4993219e7a50d3a84c6d5aa7949f.jpg: 640x640 1 person, 10.8ms
# image 27/165 /content/yolov5/visual_object_tracking-2/test/images/0070_jpg.rf.04b2a54a69a457cb6cde53162eb7b039.jpg: 640x640 1 bird1, 10.7ms
# image 28/165 /content/yolov5/visual_object_tracking-2/test/images/0073_jpg.rf.a25f57b0f1d446c65b30db8767092950.jpg: 640x640 1 Biker, 9.4ms
# image 29/165 /content/yolov5/visual_object_tracking-2/test/images/0074_jpg.rf.bdaa3b0a5d403deea834e4eda86845b6.jpg: 640x640 1 person, 9.5ms
# image 30/165 /content/yolov5/visual_object_tracking-2/test/images/0080_jpg.rf.e5361a2c36289a86dd406a6e05434213.jpg: 640x640 1 Biker, 9.4ms
# image 31/165 /content/yolov5/visual_object_tracking-2/test/images/0082_jpg.rf.9de3560ed4fde762074ac1dde134d43c.jpg: 640x640 1 bird1, 9.5ms
# image 32/165 /content/yolov5/visual_object_tracking-2/test/images/0083_jpg.rf.c6765c8d9903deac68c8591a4bee9fe9.jpg: 640x640 1 blurcar, 9.2ms
# image 33/165 /content/yolov5/visual_object_tracking-2/test/images/0085_jpg.rf.5e078059ab34bec2a30a703eb2c983c0.jpg: 640x640 1 person, 9.1ms
# image 34/165 /content/yolov5/visual_object_tracking-2/test/images/0085_jpg.rf.ba4e7edd54f965b3ba9f83faeaf077f9.jpg: 640x640 1 blurcar, 9.1ms
# image 35/165 /content/yolov5/visual_object_tracking-2/test/images/0087_jpg.rf.51e0a41aacc95f547a741cc517073167.jpg: 640x640 1 person, 9.2ms
# image 36/165 /content/yolov5/visual_object_tracking-2/test/images/0088_jpg.rf.0481e903b5f2b2830889dfdd4f8b4ca1.jpg: 640x640 1 Biker, 9.2ms
# image 37/165 /content/yolov5/visual_object_tracking-2/test/images/0088_jpg.rf.fc62fe91434ea6b3ce5bb4bfe6f7bf60.jpg: 640x640 1 person, 9.2ms
# image 130/165 /content/yolov5/visual_object_tracking-2/test/images/0332_jpg.rf.6a571cbaa01231b0cb754bff4021b032.jpg: 640x640 1 bird1, 1 blurcar, 8.2ms
# image 131/165 /content/yolov5/visual_object_tracking-2/test/images/0335_jpg.rf.fc12297f927919f182abea3644a8e2c0.jpg: 640x640 1 bird1, 8.2ms
# image 132/165 /content/yolov5/visual_object_tracking-2/test/images/0351_jpg.rf.19a6d03f7d73fa46fc378ce4e37180ae.jpg: 640x640 1 bird1, 8.2ms
# image 133/165 /content/yolov5/visual_object_tracking-2/test/images/0357_jpg.rf.72766d13d86c7f3389160cbc21fd7398.jpg: 640x640 1 bird1, 8.2ms
# image 134/165 /content/yolov5/visual_object_tracking-2/test/images/0360_jpg.rf.c325613f01a3768866af78a86f2bc287.jpg: 640x640 1 bird1, 8.2ms
# image 135/165 /content/yolov5/visual_object_tracking-2/test/images/0361_jpg.rf.f23909e6fdc7f0857a76cc6f4d2a5c64.jpg: 640x640 1 bird1, 8.2ms
# image 136/165 /content/yolov5/visual_object_tracking-2/test/images/0362_jpg.rf.2037571ee839a2c424aeb7979d202874.jpg: 640x640 1 blurcar, 8.2ms
# image 137/165 /content/yolov5/visual_object_tracking-2/test/images/0372_jpg.rf.292e12f83528c363da701e46dfcaf879.jpg: 640x640 1 blurcar, 11.3ms
# image 138/165 /content/yolov5/visual_object_tracking-2/test/images/0377_jpg.rf.02d932ea0214ccfb5daab64691f5af71.jpg: 640x640 1 blurcar, 8.2ms
# image 139/165 /content/yolov5/visual_object_tracking-2/test/images/0378_jpg.rf.d8218be59bb30713178e5bb280725456.jpg: 640x640 1 blurcar, 8.6ms
# image 140/165 /content/yolov5/visual_object_tracking-2/test/images/0394_jpg.rf.3d45da0a9e7af425d8d1d5e9cc04fd3a.jpg: 640x640 1 bird1, 8.3ms
# image 141/165 /content/yolov5/visual_object_tracking-2/test/images/0402_jpg.rf.76ece9dc14875c5f885267db8aeebb36.jpg: 640x640 1 blurcar, 8.5ms
# image 142/165 /content/yolov5/visual_object_tracking-2/test/images/0411_jpg.rf.c608bec89802fafc53ea6eca11f4c593.jpg: 640x640 1 blurcar, 8.2ms
# image 143/165 /content/yolov5/visual_object_tracking-2/test/images/0418_jpg.rf.f6f6136f07771af7d3c771a0a7e127cc.jpg: 640x640 1 blurcar, 9.3ms
# image 144/165 /content/yolov5/visual_object_tracking-2/test/images/0420_jpg.rf.b5256cb2bd71f52c9a7a2a62c5680e4c.jpg: 640x640 1 blurcar, 9.0ms
# image 145/165 /content/yolov5/visual_object_tracking-2/test/images/0421_jpg.rf.a7bc8458e9e450765b8c8377635a12d7.jpg: 640x640 1 blurcar, 8.2ms
# image 146/165 /content/yolov5/visual_object_tracking-2/test/images/0427_jpg.rf.2dddd2662c22bce60cf60f2d4ed31db8.jpg: 640x640 1 blurcar, 8.2ms
# image 147/165 /content/yolov5/visual_object_tracking-2/test/images/0428_jpg.rf.6ffb97e35e1c882d25bf6d212870d471.jpg: 640x640 1 blurcar, 8.2ms
# image 148/165 /content/yolov5/visual_object_tracking-2/test/images/0429_jpg.rf.b102eb24da52662fa148c5630d8850bc.jpg: 640x640 1 blurcar, 8.2ms
# image 149/165 /content/yolov5/visual_object_tracking-2/test/images/0436_jpg.rf.620e9edc01ba1f1cc1d07d8e7bf46648.jpg: 640x640 1 blurcar, 8.2ms
# image 150/165 /content/yolov5/visual_object_tracking-2/test/images/0438_jpg.rf.a0a1b06072578ccfa1777026576a65b5.jpg: 640x640 1 blurcar, 8.2ms
# image 151/165 /content/yolov5/visual_object_tracking-2/test/images/0446_jpg.rf.9ae707d4258f1821b0a1302a6ee26083.jpg: 640x640 1 blurcar, 8.2ms
# image 152/165 /content/yolov5/visual_object_tracking-2/test/images/0451_jpg.rf.39c17fd62e3819bb648c07f392235ab1.jpg: 640x640 1 blurcar, 8.2ms
# image 153/165 /content/yolov5/visual_object_tracking-2/test/images/0456_jpg.rf.6ea4ef7377db47c468840bf2a95ca7b3.jpg: 640x640 1 blurcar, 8.2ms
# image 154/165 /content/yolov5/visual_object_tracking-2/test/images/0461_jpg.rf.a34288a2aebfe9acf02d99c149429e58.jpg: 640x640 1 blurcar, 8.2ms
# image 155/165 /content/yolov5/visual_object_tracking-2/test/images/0463_jpg.rf.9eaa4cabb04015bfac081ec06992c955.jpg: 640x640 1 blurcar, 8.5ms
# image 156/165 /content/yolov5/visual_object_tracking-2/test/images/0464_jpg.rf.cb8f5269006c24a76923352133a55ec8.jpg: 640x640 1 blurcar, 9.8ms
# image 157/165 /content/yolov5/visual_object_tracking-2/test/images/0466_jpg.rf.463bb000d60fcf7b5b254729e39874ec.jpg: 640x640 1 blurcar, 8.2ms
# image 158/165 /content/yolov5/visual_object_tracking-2/test/images/0469_jpg.rf.61f5082d15c7488ccc209fa5f06fc364.jpg: 640x640 1 blurcar, 8.2ms
# image 159/165 /content/yolov5/visual_object_tracking-2/test/images/0481_jpg.rf.be7b9de182315b99a38e74f7cc9230ac.jpg: 640x640 1 blurcar, 8.2ms
# image 160/165 /content/yolov5/visual_object_tracking-2/test/images/0487_jpg.rf.2345b85fee0391fca0bc2d9ddf087a55.jpg: 640x640 1 blurcar, 8.2ms
# image 161/165 /content/yolov5/visual_object_tracking-2/test/images/0489_jpg.rf.507d8f2f081a4ad492897b378b679dad.jpg: 640x640 1 blurcar, 8.2ms
# image 162/165 /content/yolov5/visual_object_tracking-2/test/images/0500_jpg.rf.ba74d02f190a6e58d1e64dddb475644a.jpg: 640x640 1 blurcar, 8.2ms
# image 163/165 /content/yolov5/visual_object_tracking-2/test/images/0508_jpg.rf.d1961c048d92cd89a3542536b9906ab4.jpg: 640x640 1 blurcar, 8.5ms
# image 164/165 /content/yolov5/visual_object_tracking-2/test/images/0529_jpg.rf.09af135abacd3713d4f9ce742ba57479.jpg: 640x640 1 blurcar, 8.2ms
# image 165/165 /content/yolov5/visual_object_tracking-2/test/images/0535_jpg.rf.d3de00b197f132ca4d1a7c9f44eb217c.jpg: 640x640 1 blurcar, 8.2ms
# Speed: 0.5ms pre-process, 9.1ms inference, 0.9ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/exp3

# %% [markdown]
# # Visualizing training images

# %%
import glob
from IPython.display import Image, display

for imageName in glob.glob('/content/yolov5/runs/detect/exp3/*.jpg'):
    display(Image(filename=imageName))
    print("\n")

# %% [markdown]
# # Saving Trained Weights on google drive for future use

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# %cp /content/yolov5/runs/train/yolov5s_results/weights/best.pt /content/gdrive/My\ Drive

# %% [markdown]
# # Reference for the code
#
# https://roboflow.com/models/object-detection
